# %% [markdown]
# # Analýza plánovaných hodin na učitele (ve skupině – např. katedra/fakulta) v daném časovém období (gql_ug + gql_events)

# %% [markdown]
# # Zadání
#
# - Vytvořit GQL dotaz na základě existující federace
# - Definovat transformaci gql response table rows
# - Vytvořit kontingenční tabulku
# - Vytvořit koláčový graf
# - Vytvořit sunburst
# - výsledek realizujte jako ipynb notebook (autentizace jménem a heslem, realizace aiohttp,  transformace response, vytvoření tabulky, vytvoření grafů

# %% [markdown]
# ## Projektové dny
#
# - 25.4.2024
# - 21.5.2024
# - 10.6.2024

# %% [markdown]
# # Main
#
# 1-2. Hodina
# Basics, How to, ...

# %%
import json
import re

with open('rozvrh.json', encoding='utf-8') as inputFile:
    data = json.load(inputFile)

# %%
sourceTable = []

for event in data['events']:
    teachersNames = event.get ("teachersNames", [])
    teachersCount = len(teachersNames)
    if not "lessonsCount" in event:
        continue
    for teachers in teachersNames:
        teacher_name = teachers.split(' (')[0].strip().replace(',', '')
        row = {}
        row["lessonsCount"] = event["lessonsCount"] /teachersCount
        row["lessonFormName"] = event["lessonFormName"]
        row["teachersIds"] = event["teachersIds"]
        row["teachers"] = teachers
        sourceTable.append(row)

print(sourceTable[:10])

with open('resultX.json',"w", encoding='utf-8') as outputFile:
    json.dump(sourceTable, outputFile)
# Out:
# [{'lessonsCount': 2.0, 'lessonFormName': 'P', 'teachersIds': [403], 'teachers': 'Kuben, Jaromír'}, {'lessonsCount': 2.0, 'lessonFormName': 'CV', 'teachersIds': [669], 'teachers': 'Biolek Dalibor (669)'}, {'lessonsCount': 1.0, 'lessonFormName': 'P', 'teachersIds': [2883], 'teachers': 'Františ Petr (2883)'}, {'lessonsCount': 1.0, 'lessonFormName': 'P', 'teachersIds': [3899], 'teachers': 'Bajer Josef (3899)'}, {'lessonsCount': 2.0, 'lessonFormName': 'P', 'teachersIds': [669], 'teachers': 'Biolek Dalibor (669)'}, {'lessonsCount': 1.0, 'lessonFormName': 'P', 'teachersIds': [3899], 'teachers': 'Bajer Josef (3899)'}, {'lessonsCount': 2.0, 'lessonFormName': 'P', 'teachersIds': [669], 'teachers': 'Biolek Dalibor (669)'}, {'lessonsCount': 1.0, 'lessonFormName': 'P', 'teachersIds': [2883], 'teachers': 'Františ Petr (2883)'}, {'lessonsCount': 1.0, 'lessonFormName': 'LAB', 'teachersIds': [3899], 'teachers': 'Bajer, Josef'}, {'lessonsCount': 1.0, 'lessonFormName': 'P', 'teachersIds': [3899], 'teachers': 'Bajer, Josef'}]

# %% [markdown]
# # Dotaz

# %%
{
  eventPresencePage {
    user {
      id                   #Needed for identification
      email
      fullname
      membership {         #Group membership (K-209, FVT, ...)
        group {
          id               #Instead of name will be used ID
          name
        }
      }
    }
    event {
      id                   #Based on ID of event, we will be able to determine the subject
      name
      startdate            
      enddate              #EndDate - StartDate = Lesson lenght in minutes
      eventType{
        id                 #EventType - Type of class (Zkouska, P, SEM, CV, ...)
        name
      }
    }
    invitationType {
      id                   #By InvitationType we will determine who is Teacher (Organizator)
      name
    }
  }
  
}
# Out:
#   Cell In[2], line 4
#     id                   #Needed for identification
#     ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
{
  groupPage {
    memberships {
      user {
        id
        fullname
        
        events(where:{_and: [ {startdate: {_ge: ""}}, {enddate: {_le: ""}}]}) {
          presences {
            id
          
          }
        }
      }
    }
  }
}

# %% [markdown]
# {
#   groupPage {
#     memberships {
#       user {
#         id
#         fullname
#
#         events(where:{_and: [ {startdate: {_ge: ""}}, {enddate: {_le: ""}}]}) {
#           presences {
#             id
#
#           }
#         }
#       }
#     }
#   }
# }

# %% [markdown]
# # Getting the data from API
# This part of code were supplied from the teacher

# %%
pip install aiohttp asyncio
# Out:
# Collecting aiohttp
#   Downloading aiohttp-3.9.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.5 kB)
# Collecting asyncio
#   Downloading asyncio-3.4.3-py3-none-any.whl.metadata (1.7 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp)
#   Downloading aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp) (23.1.0)
# Collecting frozenlist>=1.1.1 (from aiohttp)
#   Downloading frozenlist-1.4.1-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp)
#   Downloading multidict-6.0.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp)
#   Downloading yarl-1.9.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (31 kB)
# Requirement already satisfied: idna>=2.0 in /opt/conda/lib/python3.11/site-packages (from yarl<2.0,>=1.0->aiohttp) (3.4)
# Downloading aiohttp-3.9.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 3.9 MB/s eta 0:00:0000:0100:01m
# Downloading asyncio-3.4.3-py3-none-any.whl (101 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.8/101.8 kB 5.3 MB/s eta 0:00:00
# Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Downloading frozenlist-1.4.1-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (272 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 272.3/272.3 kB 9.9 MB/s eta 0:00:00
# Downloading multidict-6.0.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (128 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.7/128.7 kB 7.2 MB/s eta 0:00:00
# Downloading yarl-1.9.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (328 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 328.1/328.1 kB 8.7 MB/s eta 0:00:00:00:01
# Installing collected packages: asyncio, multidict, frozenlist, yarl, aiosignal, aiohttp
# Successfully installed aiohttp-3.9.5 aiosignal-1.3.1 asyncio-3.4.3 frozenlist-1.4.1 multidict-6.0.5 yarl-1.9.4
# Note: you may need to restart the kernel to use updated packages.

# %%
import aiohttp
import asyncio
from itertools import product
from functools import reduce
from typing import Dict, List
import datetime
import json

async def getToken(username, password):
    keyurl = "http://host.docker.internal:33001/oauth/login3"    #default gateway of Docker - Needed if using linux, otherwise localhost
    async with aiohttp.ClientSession() as session:
        async with session.get(keyurl) as resp:
            print(resp.status)
            keyJson = await resp.json()
            print(keyJson)
        payload = {"key": keyJson["key"], "username": username, "password": password}
        async with session.post(keyurl, json=payload) as resp:
            # print(resp.status)
            tokenJson = await resp.json()
            # print(tokenJson)
    return tokenJson.get("token", None)

def query(q, token):
    async def post(variables):
        gqlurl = "http://host.docker.internal:33001/api/gql"
        payload = {"query": q, "variables": variables}
        # headers = {"Authorization": f"Bearer {token}"}
        cookies = {'authorization': token}
        async with aiohttp.ClientSession() as session:
            # print(headers, cookies)
            async with session.post(gqlurl, json=payload, cookies=cookies) as resp:
                # print(resp.status)
                if resp.status != 200:
                    text = await resp.text()
                    print(text)
                    return text
                else:
                    response = await resp.json()
                    return response
    return post


def enumerateAttrs(attrs):
    for key, value in attrs.items():
        names = value.split(".")
        name = names[0]
        yield key, name


def flattenList(inList, outItem, attrs):
    for item in inList:
        assert isinstance(item, dict), f"in list only dicts are expected"
        for row in flatten(item, outItem, attrs):
            # print("flatList", row)
            yield row

           
def flattenDict(inDict, outItem, attrs):
    result = {**outItem}
    print("flatDict.result", result)
    complexAttrs = []
    for key, value in enumerateAttrs(attrs):
        attributeValue = inDict.get(value, None)
        if isinstance(attributeValue, list):
            complexAttrs.append((key, value))
        elif isinstance(attributeValue, dict):
            complexAttrs.append((key, value))
        else:
            result[key] = attributeValue
            
    lists = []
    for key, value in complexAttrs:
        attributeValue = inDict.get(value, None)
        prefix = f"{value}."
        prefixlen = len(prefix)
        subAttrs = {key: value[prefixlen:] for key, value in attrs.items() if value.startswith(prefix)}
        items = list(flatten(attributeValue, result, subAttrs))
        lists.append(items)

    if len(lists) == 0:
        yield result
    else:
        for element in product(*lists):
            reduced = reduce(lambda a, b: {**a, **b}, element, {})
            yield reduced


def flatten(inData, outItem, attrs):
    if isinstance(inData, dict):
        for item in flattenDict(inData, outItem, attrs):
            yield item
    elif isinstance(inData, list):
        for item in flattenList(inData, outItem, attrs):
            yield item
    else:
        assert False, f"Unexpected type on inData {inData}"


username = "john.newbie@world.com"
password = "john.newbie@world.com"
 
queryStr = """
{
  result: eventPresencePage {
    user {
      id
      fullname
      membership {
        group {
          id
          name
        }
      }
    }
    event {
      id
      name
      startdate
      enddate
      eventType {
        id
        name
      }
    }
    invitationType {
      id
      name
    }
  }
}
"""
 
 
mappers = {
    "id": "user.id",
    "fullname": "user.fullname",
    "groupid": "user.membership.group.id",
    "groupname": "user.membership.group.name",
    "eventid": "event.id",
    "eventName": "event.name",
    "startdate": "event.startdate",
    "enddate": "event.enddate",
    "eventTypeid": "event.eventType.id",
    "eventTypename": "event.eventType.name",
    "invitationTypeid": "event.invitationType.id",
    "invitationTypeName": "event.invitationType.name"
}

async def toTable(data: List[Dict]) -> List[Dict]:
    sourceTable = []
    specific_group = "K-209"
    for item in data:
        user = item.get('user', {})
        event = item.get('event', {})
        invitation_type = item.get('invitationType', {}).get('name', None)
        
        if user and event and invitation_type:
            user_groups = [group['group']['name'] for group in user.get('membership', [])]
            if specific_group in user_groups:
                row = {
                    "membership": specific_group,
                    "teacher_name": user.get('fullname', ''),
                    "teacher_id": user.get('id', ''),
                    "event_type": event['eventType'].get('name', ''),
                    "invitation_type": invitation_type,
                    "lesson_length": get_lesson_length(event.get('startdate', ''), event.get('enddate', ''))
                }
                sourceTable.append(row)
    return sourceTable

def get_lesson_length(start_date: str, end_date: str) -> float:
    start_datetime = datetime.datetime.fromisoformat(start_date)
    end_datetime = datetime.datetime.fromisoformat(end_date)
    return (end_datetime - start_datetime).total_seconds() / 60


def format_to_json(data):
    return json.dumps(data, indent=4)


async def fullPipe():
    global pandasData
    token = await getToken(username, password)
    #print(token)
    qfunc = query(queryStr, token)
    #print(qfunc)
    response = await qfunc({})
    #print(response)
    data = response.get("data", None)
    result = data.get("result", None)
    formatedData=format_to_json(result)
    #print(formatedData)
    #flatData = flatten(result, {}, mappers)
    #print(flatData)
    pandasData = await toTable(formatedData)
    print(pandasData)
    #return pandasData

await fullPipe()


    

#print(list(flatData))
# Out:
# 200
# {'key': 'urEswOth1xfRzfSKLtulEGk4GpmiaVKX'}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 200
#     197     print(pandasData)
#     198     #return pandasData
# --> 200 await fullPipe()
#     205 #print(list(flatData))
#
# Cell In[33], line 196, in fullPipe()
#     192 formatedData=format_to_json(result)
#     193 #print(formatedData)
#     194 #flatData = flatten(result, {}, mappers)
#     195 #print(flatData)
# --> 196 pandasData = await toTable(formatedData)
#     197 print(pandasData)
#
# Cell In[33], line 154, in toTable(data)
#     151 specific_group = "K-209"
#     153 for item in data: #['data']['eventPresencePage']:
# --> 154     is_teacher = item['invitationType']['name'] #In production 'name' use will be changed for ID
#     156     if is_teacher == "organizátor": #In production use will be changed for ID
#     157         user_groups = [group['group']['name'] for group in item['user']['membership']] #In production 'name' use will be changed for ID
#
# TypeError: string indices must be integers, not 'str'

# %%
pip install pandas aiohttp plotly.express asyncio nbformat
# Out:
# Requirement already satisfied: pandas in /opt/conda/lib/python3.11/site-packages (2.1.1)
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.11/site-packages (3.9.5)
# Requirement already satisfied: plotly.express in /opt/conda/lib/python3.11/site-packages (0.4.1)
# Requirement already satisfied: asyncio in /opt/conda/lib/python3.11/site-packages (3.4.3)
# Requirement already satisfied: nbformat in /opt/conda/lib/python3.11/site-packages (5.9.2)
# Requirement already satisfied: numpy>=1.23.2 in /opt/conda/lib/python3.11/site-packages (from pandas) (1.24.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.11/site-packages (from aiohttp) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.11/site-packages (from aiohttp) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.11/site-packages (from aiohttp) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp) (1.9.4)
# Requirement already satisfied: plotly>=4.1.0 in /opt/conda/lib/python3.11/site-packages (from plotly.express) (5.22.0)
# Requirement already satisfied: statsmodels>=0.9.0 in /opt/conda/lib/python3.11/site-packages (from plotly.express) (0.14.0)
# Requirement already satisfied: scipy>=0.18 in /opt/conda/lib/python3.11/site-packages (from plotly.express) (1.11.3)
# Requirement already satisfied: patsy>=0.5 in /opt/conda/lib/python3.11/site-packages (from plotly.express) (0.5.3)
# Requirement already satisfied: fastjsonschema in /opt/conda/lib/python3.11/site-packages (from nbformat) (2.18.1)
# Requirement already satisfied: jsonschema>=2.6 in /opt/conda/lib/python3.11/site-packages (from nbformat) (4.19.1)
# Requirement already satisfied: jupyter-core in /opt/conda/lib/python3.11/site-packages (from nbformat) (5.4.0)
# Requirement already satisfied: traitlets>=5.1 in /opt/conda/lib/python3.11/site-packages (from nbformat) (5.11.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat) (0.10.6)
# Requirement already satisfied: six in /opt/conda/lib/python3.11/site-packages (from patsy>=0.5->plotly.express) (1.16.0)
# Requirement already satisfied: tenacity>=6.2.0 in /opt/conda/lib/python3.11/site-packages (from plotly>=4.1.0->plotly.express) (8.3.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.11/site-packages (from plotly>=4.1.0->plotly.express) (23.2)
# Requirement already satisfied: idna>=2.0 in /opt/conda/lib/python3.11/site-packages (from yarl<2.0,>=1.0->aiohttp) (3.4)
# Requirement already satisfied: platformdirs>=2.5 in /opt/conda/lib/python3.11/site-packages (from jupyter-core->nbformat) (3.11.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import aiohttp
import asyncio
import json
import plotly.express as px
import pandas as pd
from itertools import product
from functools import reduce

async def getToken(username, password):
    keyurl = "http://host.docker.internal:33001/oauth/login3"
    async with aiohttp.ClientSession() as session:
        async with session.get(keyurl) as resp:
            keyJson = await resp.json()

        payload = {"key": keyJson["key"], "username": username, "password": password}
        async with session.post(keyurl, json=payload) as resp:
            tokenJson = await resp.json()
    return tokenJson.get("token", None)


def query(q, token):
    async def post(variables):
        gqlurl = "http://host.docker.internal:33001/api/gql"
        payload = {"query": q, "variables": variables}
        cookies = {'authorization': token}
        async with aiohttp.ClientSession() as session:
            async with session.post(gqlurl, json=payload, cookies=cookies) as resp:
                if resp.status != 200:
                    text = await resp.text()
                    print(text)
                    return text
                else:
                    response = await resp.json()
                    return response
    return post

def enumerateAttrs(attrs):
    for key, value in attrs.items():
        names = value.split(".")
        name = names[0]
        yield key, name

def flattenList(inList, outItem, attrs):
    for item in inList:
        assert isinstance(item, dict), f"in list only dicts are expected"
        for row in flatten(item, outItem, attrs):
            yield row

def flattenDict(inDict, outItem, attrs):
    result = {**outItem}
    complexAttrs = []
    for key, value in enumerateAttrs(attrs):
        attributeValue = inDict.get(value, None)
        if isinstance(attributeValue, list):
            complexAttrs.append((key, value))
        elif isinstance(attributeValue, dict):
            complexAttrs.append((key, value))
        else:
            result[key] = attributeValue
    lists = []
    for key, value in complexAttrs:
        attributeValue = inDict.get(value, None)
        prefix = f"{value}."
        prefixlen = len(prefix)
        subAttrs = {key: value[prefixlen:] for key, value in attrs.items() if value.startswith(prefix)}
        items = list(flatten(attributeValue, result, subAttrs))
        lists.append(items)
                     
    if len(lists) == 0:
        yield result
    else:
        for element in product(*lists):
            reduced = reduce(lambda a, b: {**a, **b}, element, {})
            yield reduced

def flatten(inData, outItem, attrs):
    print("Trying  flatten")
    if isinstance(inData, dict):
        for item in flattenDict(inData, outItem, attrs):
            print("Trying Dict flatten")
            yield item
            print("Successful Dict flatten")
    elif isinstance(inData, list):
        for item in flattenList(inData, outItem, attrs):
            print("Trying List flatten")
            yield item
            print("Successful List flatten")
    else:
        assert False, f"Unexpected type on inData {inData}"

username = "john.newbie@world.com"
password = "john.newbie@world.com"

queryStr = """
{
  groupPage {
    memberships {
      user {
        id
        fullname
        
        events(where:{_and: [ {startdate: {_ge: "2023-03-19T08:00:00"}}, {enddate: {_le: "2023-05-19T08:00:00"}}]}) {
          presences {
            id
          
          }
        }
      }
    }
  }
}
"""

mappers = {
    "userID": "memberships.user.id",
    "userFullname": "memberships.user.fullname",
    "presencesID": "memberships.user.events.presences.id",
    #"startDate": "memberships.user.events.startdate",
    #"endDate": "memberships.user.events.enddate",
    "presencesCount": "presencesCount",
}


async def fullPipe():
    token = await getToken(username, password)
    qfunc = query(queryStr, token)
    response = await qfunc({})
    data = response.get("data", None)
    result = data.get("groupPage", None)
    resultMapped = list(map(lambda project: {**project, "presencesCount": len(project.get("presencesID", []))}, result))
    flatData = flatten(resultMapped, {}, mappers)
    return list(flatData)

async def main():
     flatData = await fullPipe()
     print(flatData)
#    with open('resultNotebook.json', "w", encoding='utf-8') as outputFile:
#        json.dump(flatData, outputFile)
await main()
# Out:
# {'data': {'groupPage': [{'memberships': [{'user': {'id': '2d9dc5ca-a4a2-11ed-b9df-0242ac120003', 'fullname': 'John Newbie', 'events': []}}, {'user': {'id': '2d9dc868-a4a2-11ed-b9df-0242ac120003', 'fullname': 'Julia Newbie', 'events': []}}, {'user': {'id': '2d9dc9a8-a4a2-11ed-b9df-0242ac120003', 'fullname': 'Johnson Newbie', 'events': []}}, {'user': {'id': '2d9dcbec-a4a2-11ed-b9df-0242ac120003', 'fullname': 'Jepeto Newbie', 'events': []}}, {'user': {'id': '89d1e724-ae0f-11ed-9bd8-0242ac110002', 'fullname': 'Jana Newbie', 'events': [{'presences': [{'id': '89d1e684-ae0f-11ed-9bd8-0242ac110002'}, {'id': '89d1f2d2-ae0f-11ed-9bd8-0242ac110002'}, {'id': '89d1f3ae-ae0f-11ed-9bd8-0242ac110002'}, {'id': '89d1f412-ae0f-11ed-9bd8-0242ac110002'}, {'id': '89d1f46c-ae0f-11ed-9bd8-0242ac110002'}, {'id': '89d1f4c6-ae0f-11ed-9bd8-0242ac110002'}, {'id': '89d1f520-ae0f-11ed-9bd8-0242ac110002'}, {'id': '89d1f570-ae0f-11ed-9bd8-0242ac110002'}, {'id': '89d1f5ca-ae0f-11ed-9bd8-0242ac110002'}, {'id': '89d1f624-ae0f-11ed-9bd8-0242ac110002'}]}]}}, {'user': {'id': '89d1f34a-ae0f-11ed-9bd8-0242ac110002', 'fullname': 'Jolana Newbie', 'events': [{'presences': [{'id': '89d1e684-ae0f-11ed-9bd8-0242ac110002'}, {'id': '89d1f2d2-ae0f-11ed-9bd8-0242ac110002'}, {'id': '89d1f3ae-ae0f-11ed-9bd8-0242ac110002'}, {'id': '89d1f412-ae0f-11ed-9bd8-0242ac110002'}, {'id': '89d1f46c-ae0f-11ed-9bd8-0242ac110002'}, {'id': '89d1f4c6-ae0f-11ed-9bd8-0242ac110002'}, {'id': '89d1f520-ae0f-11ed-9bd8-0242ac110002'}, {'id': '89d1f570-ae0f-11ed-9bd8-0242ac110002'}, {'id': '89d1f5ca-ae0f-11ed-9bd8-0242ac110002'}, {'id': '89d1f624-ae0f-11ed-9bd8-0242ac110002'}]}]}}, {'user': {'id': '89d1f3cc-ae0f-11ed-9bd8-0242ac110002', 'fullname': 'Jitka Newbie', 'events': [{'presences': [{'id': '89d1e684-ae0f-11ed-9bd8-0242ac110002'}, {'id': '89d1f2d2-ae0f-11ed-9bd8-0242ac110002'}, {'id': '89d1f3ae-ae0f-11ed-9bd8-0242ac110002'}, {'id': '89d1f412-ae0f-11ed-9bd8-0242ac110002'}, {'id': '89d1f46c-ae0f-11ed-9bd8-0242ac110002'}, {'id': '89d1f4c6-ae0f-11ed-9bd8-0242ac110002'}, {'id': '89d1f520-ae0f-11ed-9bd8-0242ac110002'}, {'id': '89d1f570-ae0f-11ed-9bd8-0242ac110002'}, {'id': '89d1f5ca-ae0f-11ed-9bd8-0242ac110002'}, {'id': '89d1f624-ae0f-11ed-9bd8-0242ac110002'}]}]}}, {'user': {'id': '89d1f430-ae0f-11ed-9bd8-0242ac110002', 'fullname': 'Jaroslava Newbie', 'events': [{'presences': [{'id': '89d1e684-ae0f-11ed-9bd8-0242ac110002'}, {'id': '89d1f2d2-ae0f-11ed-9bd8-0242ac110002'}, {'id': '89d1f3ae-ae0f-11ed-9bd8-0242ac110002'}, {'id': '89d1f412-ae0f-11ed-9bd8-0242ac110002'}, {'id': '89d1f46c-ae0f-11ed-9bd8-0242ac110002'}, {'id': '89d1f4c6-ae0f-11ed-9bd8-0242ac110002'}, {'id': '89d1f520-ae0f-11ed-9bd8-0242ac110002'}, {'id': '89d1f570-ae0f-11ed-9bd8-0242ac110002'}, {'id': '89d1f5ca-ae0f-11ed-9bd8-0242ac110002'}, {'id': '89d1f624-ae0f-11ed-9bd8-0242ac110002'}]}]}}, {'user': {'id': '89d1f48a-ae0f-11ed-9bd8-0242ac110002', 'fullname': 'Lada Newbie', 'events': [{'presences': [{'id': '89d1e684-ae0f-11ed-9bd8-0242ac110002'}, {'id': '89d1f2d2-ae0f-11ed-9bd8-0242ac110002'}, {'id': '89d1f3ae-ae0f-11ed-9bd8-0242ac110002'}, {'id': '89d1f412-ae0f-11ed-9bd8-0242ac110002'}, {'id': '89d1f46c-ae0f-11ed-9bd8-0242ac110002'}, {'id': '89d1f4c6-ae0f-11ed-9bd8-0242ac110002'}, {'id': '89d1f520-ae0f-11ed-9bd8-0242ac110002'}, {'id': '89d1f570-ae0f-11ed-9bd8-0242ac110002'}, {'id': '89d1f5ca-ae0f-11ed-9bd8-0242ac110002'}, {'id': '89d1f624-ae0f-11ed-9bd8-0242ac110002'}]}]}}, {'user': {'id': '89d1f4e4-ae0f-11ed-9bd8-0242ac110002', 'fullname': 'Ludmila Newbie', 'events': [{'presences': [{'id': '89d1e684-ae0f-11ed-9bd8-0242ac110002'}, {'id': '89d1f2d2-ae0f-11ed-9bd8-0242ac110002'}, {'id': '89d1f3ae-ae0f-11ed-9bd8-0242ac110002'}, {'id': '89d1f412-ae0f-11ed-9bd8-0242ac110002'}, {'id': '89d1f46c-ae0f-11ed-9bd8-0242ac110002'}, {'id': '89d1f4c6-ae0f-11ed-9bd8-0242ac110002'}, {'id': '89d1f520-ae0f-11ed-9bd8-0242ac110002'}, {'id': '89d1f570-ae0f-11ed-9bd8-0242ac110002'}, {'id': '89d1f5ca-ae0f-11ed-9bd8-0242ac110002'}, {'id': '89d1f624-ae0f-11ed-9bd8-024 ...
# <generator object flatten at 0x7f51c63c27a0>
